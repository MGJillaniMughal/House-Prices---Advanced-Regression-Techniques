# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
train_df=pd.read_csv("train.csv")
test_df=pd.read_csv("test.csv")

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
train_df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test_df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 1454         Lvl    AllPub  ...           0        0    NaN    NaN
# 1455         Lvl    AllPub  ...           0        0    NaN    NaN
# 1456         Lvl    AllPub  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
train_df.shape
# Out:
# (1460, 81)

# %%
test_df.shape
# Out:
# (1459, 80)

# %%
train_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(train_df.isnull(),cbar=False,yticklabels=False,cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
train_df.drop(['Alley', 'PoolQC', 'FireplaceQu'], axis = 1, inplace = True)

# %%
train_df.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 78, dtype: int64

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train_df.describe().T.style.background_gradient(subset = 'mean', cmap = 'Greens').background_gradient(subset = '50%', cmap = 'Reds')
# Out:
# <style  type="text/css" >
# #T_02e24_row0_col1,#T_02e24_row6_col1,#T_02e24_row7_col1,#T_02e24_row12_col1,#T_02e24_row13_col1,#T_02e24_row16_col1,#T_02e24_row25_col1,#T_02e24_row36_col1{
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }#T_02e24_row0_col5,#T_02e24_row12_col5,#T_02e24_row13_col5{
#             background-color:  #fff4ef;
#             color:  #000000;
#         }#T_02e24_row1_col1,#T_02e24_row2_col1,#T_02e24_row4_col1,#T_02e24_row5_col1,#T_02e24_row8_col1,#T_02e24_row9_col1,#T_02e24_row10_col1,#T_02e24_row11_col1,#T_02e24_row14_col1,#T_02e24_row15_col1,#T_02e24_row17_col1,#T_02e24_row18_col1,#T_02e24_row19_col1,#T_02e24_row20_col1,#T_02e24_row21_col1,#T_02e24_row22_col1,#T_02e24_row23_col1,#T_02e24_row24_col1,#T_02e24_row26_col1,#T_02e24_row27_col1,#T_02e24_row28_col1,#T_02e24_row29_col1,#T_02e24_row30_col1,#T_02e24_row31_col1,#T_02e24_row32_col1,#T_02e24_row33_col1,#T_02e24_row34_col1,#T_02e24_row35_col1{
# ...

# %%
train_df.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_531c3_row0_col0,#T_531c3_row1_col1,#T_531c3_row2_col2,#T_531c3_row3_col3,#T_531c3_row4_col4,#T_531c3_row5_col5,#T_531c3_row6_col6,#T_531c3_row7_col7,#T_531c3_row8_col8,#T_531c3_row9_col9,#T_531c3_row10_col10,#T_531c3_row11_col11,#T_531c3_row12_col12,#T_531c3_row13_col13,#T_531c3_row14_col14,#T_531c3_row15_col15,#T_531c3_row16_col16,#T_531c3_row17_col17,#T_531c3_row18_col18,#T_531c3_row19_col19,#T_531c3_row20_col20,#T_531c3_row21_col21,#T_531c3_row22_col22,#T_531c3_row23_col23,#T_531c3_row24_col24,#T_531c3_row25_col25,#T_531c3_row26_col26,#T_531c3_row27_col27,#T_531c3_row28_col28,#T_531c3_row29_col29,#T_531c3_row30_col30,#T_531c3_row31_col31,#T_531c3_row32_col32,#T_531c3_row33_col33,#T_531c3_row34_col34,#T_531c3_row35_col35,#T_531c3_row36_col36,#T_531c3_row37_col37{
#             background-color:  #023858;
#             color:  #f1f1f1;
# ...

# %%
train_df[['Heating','HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'FullBath', 'HalfBath','GarageType','Functional']]
# Out:
#      Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  FullBath  \
# 0       GasA        Ex          Y      SBrkr       856       854         2
# 1       GasA        Ex          Y      SBrkr      1262         0         2
# 2       GasA        Ex          Y      SBrkr       920       866         2
# 3       GasA        Gd          Y      SBrkr       961       756         1
# 4       GasA        Ex          Y      SBrkr      1145      1053         2
# ...      ...       ...        ...        ...       ...       ...       ...
# 1455    GasA        Ex          Y      SBrkr       953       694         2
# 1456    GasA        TA          Y      SBrkr      2073         0         2
# 1457    GasA        Ex          Y      SBrkr      1188      1152         2
# 1458    GasA        Gd          Y      FuseA      1078         0         1
# 1459    GasA        Gd          Y      SBrkr      1256         0         1
#
#       HalfBath GarageType Functional
# ...

# %%
train_df.Heating.unique()
# Out:
# array(['GasA', 'GasW', 'Grav', 'Wall', 'OthW', 'Floor'], dtype=object)

# %%
train_df.HeatingQC.unique()
# Out:
# array(['Ex', 'Gd', 'TA', 'Fa', 'Po'], dtype=object)

# %%
train_df.CentralAir.unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
train_df.Functional.unique()
# Out:
# array(['Typ', 'Min1', 'Maj1', 'Min2', 'Mod', 'Maj2', 'Sev'], dtype=object)

# %%
train_df.GarageType.unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', nan, 'Basment', '2Types'],
#       dtype=object)

# %%
train_df.MSSubClass.unique
# Out:
# <bound method Series.unique of 0       60
# 1       20
# 2       60
# 3       70
# 4       60
#         ..
# 1455    60
# 1456    20
# 1457    70
# 1458    20
# 1459    20
# Name: MSSubClass, Length: 1460, dtype: int64>

# %%
train_df.MSZoning.unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
train_df.Neighborhood.unique()
# Out:
# array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object)

# %%
X = ['LotFrontage', 'LotArea', 'Street','MSZoning',
       'Utilities', 'LotConfig','LandSlope', 'Neighborhood','HouseStyle',
        'OverallQual', 'YearBuilt', 'YearRemodAdd','BsmtExposure',
       'RoofStyle', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'Heating', 'HeatingQC', 'CentralAir','FullBath','Electrical',
        'BedroomAbvGr', 'KitchenQual', 'TotRmsAbvGrd','GarageType', 'GarageYrBlt',
        'GarageArea', 'GarageQual','GarageCond', 'PoolArea', 'Fence','PavedDrive']

Y = 'SalePrice'

# %%
sns.pairplot(data = train_df, x_vars = ['MSSubClass','LotFrontage','LotArea','OverallQual'], y_vars  = ['SalePrice'], kind = 'scatter')

# %%
sns.pairplot(data = train_df, x_vars = ['OverallCond','YearBuilt','YearRemodAdd','FullBath'], y_vars = ['SalePrice'], kind = 'scatter')

# %%
sns.pairplot(data = train_df, x_vars = ['HalfBath','BedroomAbvGr','KitchenAbvGr','TotRmsAbvGrd'], y_vars = ['SalePrice'], kind = 'scatter')

# %%
sns.pairplot(data = train_df, x_vars = ['GarageYrBlt','GarageArea','PoolArea'], y_vars = ['SalePrice'], kind = 'scatter')

# %%
sns.histplot(x = 'SalePrice', data = train_df, kde = True)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
len(X)
# Out:
# 35

# %% [markdown]
# # Missing Cols

# %%
cols_missing=[col for col in X if train_df[col].isnull().any()]

# %%
cols_missing
# Out:
# ['LotFrontage',
#  'BsmtExposure',
#  'BsmtQual',
#  'BsmtCond',
#  'Electrical',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageQual',
#  'GarageCond',
#  'Fence']

# %%
n_cols = [col for col in X if train_df[col].dtype in ['int64', 'float64']]
cati_cols = [col for col in X if train_df[col].dtype == 'object']

# %%
n_cols
# Out:
# ['LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'YearBuilt',
#  'YearRemodAdd',
#  'FullBath',
#  'BedroomAbvGr',
#  'TotRmsAbvGrd',
#  'GarageYrBlt',
#  'GarageArea',
#  'PoolArea']

# %%
cati_cols
# Out:
# ['Street',
#  'MSZoning',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'HouseStyle',
#  'BsmtExposure',
#  'RoofStyle',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'GarageType',
#  'GarageQual',
#  'GarageCond',
#  'Fence',
#  'PavedDrive']

# %% [markdown]
# # Now Low Cardinality Columns

# %%
l_card_cols=[col for col in cati_cols if train_df[col].nunique()<7]
l_card_cols
# Out:
# ['Street',
#  'MSZoning',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'BsmtExposure',
#  'RoofStyle',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'GarageType',
#  'GarageQual',
#  'GarageCond',
#  'Fence',
#  'PavedDrive']

# %% [markdown]
# # Now High Cardinality Columns

# %%
h_card_cols=list(set(cati_cols)-set(l_card_cols))
h_card_cols
# Out:
# ['Neighborhood', 'HouseStyle']

# %% [markdown]
# # Now Imports Some Others Lib's

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer

# %%
num_por = Pipeline(steps = [
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('scaler', MinMaxScaler())
])

# %%
cat_por = Pipeline(steps = [
    ('imputer', SimpleImputer(strategy = 'most_frequent')),
    ('ohe', OneHotEncoder(handle_unknown = 'ignore', sparse = False))
])

# %%
prepor=ColumnTransformer(
[
    ('num',num_por,n_cols),
    ('cat',cat_por,cati_cols)
]
)

# %% [markdown]
# # Now Import Models

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dec_tree_reg_mod=DecisionTreeRegressor(max_depth=17,random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rand_for_reg=RandomForestRegressor(n_estimators=169,random_state=0)

# %%
from xgboost import XGBRegressor

# %%
xgb_reg=XGBRegressor(n_estimators=301,learing_rate=0.1,random_state=0)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# %%
clf=Pipeline(steps=[
                ('preprocessor',prepor),
                ('dec_tree_reg_mod',dec_tree_reg_mod)
            ])

# %%
my_columns=n_cols+cati_cols
x=train_df[my_columns]
y=np.log1p(train_df[Y])

# %%
sns.histplot(data=train_df,x=y,kde=True)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
x.head()
# Out:
#    LotFrontage  LotArea  OverallQual  YearBuilt  YearRemodAdd  FullBath  \
# 0         65.0     8450            7       2003          2003         2
# 1         80.0     9600            6       1976          1976         2
# 2         68.0    11250            7       2001          2002         2
# 3         60.0     9550            7       1915          1970         1
# 4         84.0    14260            8       2000          2000         2
#
#    BedroomAbvGr  TotRmsAbvGrd  GarageYrBlt  GarageArea  ...  Heating  \
# 0             3             8       2003.0         548  ...     GasA
# 1             3             6       1976.0         460  ...     GasA
# 2             3             6       2001.0         608  ...     GasA
# 3             3             7       1998.0         642  ...     GasA
# 4             4             9       2000.0         836  ...     GasA
#
#   HeatingQC CentralAir Electrical KitchenQual GarageType GarageQual  \
# ...

# %%
y.head()
# Out:
# 0    12.247699
# 1    12.109016
# 2    12.317171
# 3    11.849405
# 4    12.429220
# Name: SalePrice, dtype: float64

# %%
x.shape
# Out:
# (1460, 35)

# %%
y.shape
# Out:
# (1460,)

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (1095, 35)
# (1095,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (365, 35)
# (365,)

# %%
def Model(models):
    clf = Pipeline(steps = [
      ('preprocessor',prepor),
      ('model',models)
    ])
    clf.fit(X_train, y_train)
    print(models)
    print("Train set score:", clf.score(X_train, y_train))
    print("Test set score:", clf.score(X_test, y_test))
    print("Train set mse:", mean_squared_error(y_train, clf.predict(X_train)))
    print("Test set mse:", mean_squared_error(y_test, clf.predict(X_test)))
    print("\n")

# %% [markdown]
# # Now Check All Models

# %%
Models=[dec_tree_reg_mod,rand_for_reg,xgb_reg]
for i in Models:
    Model(i)
# Out:
# DecisionTreeRegressor(max_depth=17, random_state=0)
# Train set score: 0.9990741626469776
# Test set score: 0.6741492334246522
# Train set mse: 0.00015092536310476953
# Test set mse: 0.048459858225567816
#
#
# RandomForestRegressor(n_estimators=169, random_state=0)
# Train set score: 0.9753289187502571
# Test set score: 0.8405342382443023
# Train set mse: 0.004021755963560322
# Test set mse: 0.023715421288494593
#
#
# [18:59:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "learing_rate" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
# ...

# %%
Model(xgb_reg)
# Out:
# [18:59:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "learing_rate" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learing_rate=0.1, learning_rate=0.300000012, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=301, n_jobs=4,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, subsample=1, tree_method='exact',
# ...

# %% [markdown]
# # Now Test Dataset

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
test=test_df[my_columns]

# %%
y_pred=clf.predict(test)

# %%
y_pred
# Out:
# array([11.76369197, 11.88621856, 12.03765991, ..., 11.91773036,
#        11.44572741, 12.37159132])

# %%
y_pred=np.exp(y_pred)

# %%
y_pred
# Out:
# array([128501., 145251., 169001., ..., 149901.,  93501., 236001.])

# %% [markdown]
# # Now Submit file

# %%
sub_df=pd.read_csv("sample_submission.csv")

# %%
sub_df.head()
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570
# 3  1464  179317.477511
# 4  1465  150730.079977

# %%
df=pd.DataFrame({'Id': test_df.Id,'SalePrice':y_pred})
df.to_csv("Submission.csv",index=False)

# %%
sub=pd.read_csv("Submission.csv")

# %%
sub.head()
# Out:
#      Id      SalePrice
# 0  1461  128501.000000
# 1  1462  145251.000000
# 2  1463  169001.000000
# 3  1464  187035.845812
# 4  1465  213501.000000

# %%
sub.tail()
# Out:
#         Id  SalePrice
# 1454  2915    91501.0
# 1455  2916    89501.0
# 1456  2917   149901.0
# 1457  2918    93501.0
# 1458  2919   236001.0

# %%
sub
# Out:
#         Id      SalePrice
# 0     1461  128501.000000
# 1     1462  145251.000000
# 2     1463  169001.000000
# 3     1464  187035.845812
# 4     1465  213501.000000
# ...    ...            ...
# 1454  2915   91501.000000
# 1455  2916   89501.000000
# 1456  2917  149901.000000
# 1457  2918   93501.000000
# 1458  2919  236001.000000
#
# [1459 rows x 2 columns]
